# %%
import pandas as pd
import matplotlib.pyplot as plt
from math import sqrt
from sklearn.metrics import mean_squared_error

# %%
dataset = pd.read_csv("weather.csv")
dataset.head()

# %%
dataset.shape
# Out:
# (366, 22)

# %%
dataset.isna().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
X = dataset[["MinTemp"]]
y = dataset[["MaxTemp"]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
y_train
# Out:
#      MaxTemp
# 63      23.4
# 241     16.0
# 306     16.7
# 317     25.5
# 245     11.5
# ..       ...
# 323     23.3
# 192     17.4
# 117     28.2
# 47      20.9
# 172     20.6
#
# [292 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
plt.scatter(X_train, y_train, color="red")
plt.plot(X_train, regressor.predict(X_train), color="blue")
plt.title("Maximum Temperature vs Minimum Temperature (Training set)")
plt.xlabel("Minimum Temperature")
plt.ylabel("Maximum Temperature")
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse_on_train_dataset = sqrt(mean_squared_error(y_train, regressor.predict(X_train)))
print(rmse_on_train_dataset)
# Out:
# 4.469204207117763

# %%
plt.scatter(X_test, y_test, color="red")
plt.plot(X_train, regressor.predict(X_train), color="blue")
plt.title("Maximum Temperature vs Minimum Temperature")
plt.xlabel("Minimum Temperature")
plt.ylabel("Maximum Temperature")
plt.show()

# %%
rmse_on_test_dataset = sqrt(mean_squared_error(y_test, regressor.predict(X_test)))
print(rmse_on_test_dataset)
# Out:
# 4.124545753006096
